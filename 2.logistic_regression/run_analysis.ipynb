# %%
# run_analysis.ipynb
import pandas as pd
from activity_analysis import run_activity_analysis

# Load your dataset
df = pd.read_excel('datafinal5.xlsx')

# Run the analysis
run_activity_analysis(df)
# Out:
# === OVERALL ANALYSIS ===
# Optimization terminated successfully.
#          Current function value: 0.131750
#          Iterations 8
#                            Logit Regression Results
# ...
# Dep. Variable:      depression_binary   No. Observations:                 5281
# Model:                          Logit   Df Residuals:                     5266
# Method:                           MLE   Df Model:                           14
# Date:                Wed, 01 Oct 2025   Pseudo R-squ.:                 0.05243
# Time:                        12:15:25   Log-Likelihood:                -695.77
# converged:                       True   LL-Null:                       -734.27
# Covariance Type:            nonrobust   LLR p-value:                 1.014e-10
# ...
#                                                                                   coef    std err          z      P>|z|      [0.025      0.975]
# ...
